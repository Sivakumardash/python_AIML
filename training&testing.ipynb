# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adv=pd.read_csv(r"C:\Users\Lenovo\Desktop\july aiml\advertising.csv")
adv
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#data cleanig
adv.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
adv.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
#describe
adv.describe(include='all')
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
for i in ['TV','Radio','Newspaper']:
    sns.scatterplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#distribution plot
sns.distplot(adv.TV)
plt.show()

# %%
sns.histplot(adv.TV)
plt.show()

# %%
sns.displot(adv.TV)
plt.show()

# %%
sns.kdeplot(adv.TV)
plt.show()

# %%
sns.histplot(data=adv)
plt.show()

# %%
sns.kdeplot(data=adv,fill=True)
plt.show()

# %%
ip=adv.drop('Sales',axis=1)
op=adv.Sales

# %%
ip.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
op.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 169  284.3   10.6        6.4
# 134   36.9   38.6       65.6
# 115   75.1   35.0       52.7
# 106   25.0   11.0       29.7
# 84   213.5   43.0       33.8
# ..     ...    ...        ...
# 108   13.1    0.4       25.6
# 130    0.7   39.6        8.7
# 19   147.3   23.9       19.1
# 52   216.4   41.7       39.6
# 149   44.7   25.8       20.6
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 35   290.7    4.1        8.5
# 189   18.7   12.1       23.4
# 104  238.2   34.3        5.3
# 49    66.9   11.7       36.8
# 146  240.1    7.3        8.7
# 128  220.3   49.0        3.2
# 46    89.7    9.9       35.7
# 21   237.4    5.1       23.5
# 64   131.1   42.8       28.9
# 120  141.3   26.8       46.2
# 79   116.0    7.7       23.1
# 73   129.4    5.7       31.3
# 119   19.4   16.0       22.3
# 182   56.2    5.7       29.7
# 122  224.0    2.4       15.6
# 147  243.2   49.0       44.3
# 40   202.5   22.3       31.6
# 187  191.1   28.7       18.2
# 103  187.9   17.2       17.9
# 124  229.5   32.3       74.2
# 196   94.2    4.9        8.1
# 74   213.4   24.6       13.1
# 59   210.7   29.5        9.3
# 69   216.8   43.9       27.2
# 195   38.2    3.7       13.8
# 55   198.9   49.4       60.0
# 162  188.4   18.1       25.6
# 184  253.8   21.3       30.0
# 148   38.0   40.3       11.9
# 3    151.5   41.3       58.5
# 180  156.6    2.6        8.3
# ...

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
#
# x_train=sc.fit_transform(x_train)
# x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 1.58680247, -0.90722057, -1.11018215],
#        [-1.24590951,  1.02257771,  1.51964962],
#        [-0.80852229,  0.77446079,  0.94659506],
#        [-1.38216364, -0.87965202, -0.07513012],
#        [ 0.77614762,  1.32583173,  0.1070035 ],
#        [-0.10893174, -0.31449681, -0.65706924],
#        [ 1.25589957,  0.21619771, -1.1501627 ],
#        [ 1.64863207,  1.27758677,  0.87996081],
#        [ 0.30670061, -0.39031032, -0.03070728],
#        [ 1.38757373,  1.38096882, -1.17237412],
#        [-1.57223243,  0.23687412, -1.30120033],
#        [-0.82798717, -0.46612382, -0.82143373],
#        [-0.80394232, -0.8934363 , -1.12795128],
#        [ 1.36810886, -1.4379151 ,  0.51569357],
#        [-0.29213058, -0.28692827, -0.87918341],
#        [-1.46345812,  0.95365634, -0.43495507],
#        [ 1.53985776, -0.94168125, -0.44383964],
#        [-0.63333841, -1.61711065, -0.36387854],
#        [ 0.21510119, -0.19733049,  0.71115404],
#        [ 0.59409378, -0.03191921, -0.76368404],
# ...

# %%
#ML Model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([21.86965937,  5.96840093, 21.5725262 ,  8.92870338, 19.07115885,
#        21.89696356, 10.15210337, 18.73122059, 15.88008252, 14.99701511,
#        11.52055652, 12.17187469,  6.38795925,  7.66785623, 17.62335715,
#        23.41605483, 18.28157341, 18.16726779, 16.85067871, 21.02986492,
#         9.86736017, 19.12527631, 19.42582483, 21.25058572,  6.32365865,
#        20.77436679, 16.98986483, 21.33339157,  9.86777158, 17.06835924,
#        13.4798827 ,  8.27124267,  7.11933859,  6.07110592, 12.33560233,
#        14.50496242, 16.72999067, 18.07341009, 22.52137571, 10.15675182])

# %%
#accuracy

from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(pred,y_test)
r2=r2_score(pred,y_test)

print('mean square Error :',mse )
print('R2 score: ',r2)
# Out:
# mean square Error : 3.6779146631466872
# R2 score:  0.8744468975430693

# %%
df=pd.DataFrame({'Y_test':list(y_test),'Prediction':pred})
df
# Out:
#     Y_test  Prediction
# 0     17.8   21.869659
# 1      6.7    5.968401
# 2     20.7   21.572526
# 3      9.7    8.928703
# 4     18.2   19.071159
# 5     24.7   21.896964
# 6     10.6   10.152103
# 7     17.5   18.731221
# 8     16.0   15.880083
# 9     15.5   14.997015
# 10    11.0   11.520557
# 11    11.0   12.171875
# 12     6.6    6.387959
# 13     8.7    7.667856
# 14    16.6   17.623357
# 15    25.4   23.416055
# 16    16.6   18.281573
# 17    17.3   18.167268
# 18    19.7   16.850679
# 19    19.7   21.029865
# 20    14.0    9.867360
# 21    17.0   19.125276
# 22    18.4   19.425825
# 23    22.3   21.250586
# 24     7.6    6.323659
# 25    23.7   20.774367
# 26    19.9   16.989865
# 27    17.6   21.333392
# 28    10.9    9.867772
# 29    16.5   17.068359
# 30    15.5   13.479883
# 31    12.6    8.271243
# 32     8.1    7.119339
# 33     5.6    6.071106
# 34    14.0   12.335602
# 35    16.0   14.504962
# 36    15.0   16.729991
# 37    16.0   18.073410
# 38    20.9   22.521376
# ...

# %%
sns.lmplot(x='Y_test',y='Prediction',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.lmplot(x='Y_test',y='Prediction',data=df)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data: hours studied vs marks scored
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Features (independent variable)
y = np.array([10, 20, 30, 40, 50])            # Target (dependent variable)

# Create and train the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions for the training data and a new input
y_pred = model.predict(X)
new_input = np.array([[6]])
new_pred = model.predict(new_input)

print(f"Predicted marks for 6 hours studied: {new_pred[0]:.2f}")
print(f"Coefficient (slope): {model.coef_[0]:.2f}")
print(f"Intercept: {model.intercept_:.2f}")

# Plot the data points and the regression line
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.scatter(new_input, new_pred, color='green', marker='x', s=100, label='Prediction (6 hours)')

plt.title('Linear Regression Example: Hours Studied vs Marks Scored')
plt.xlabel('Hours Studied')
plt.ylabel('Marks Scored')
plt.legend()
plt.show()
# Out:
# Predicted marks for 6 hours studied: 60.00
# Coefficient (slope): 10.00
# Intercept: -0.00
