# %% [markdown]
# ##   seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv(r"D:\3rd year\iris\iris.data",header=None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.columns =['SL','SW','PL','PW','Flower']
iris.head()
# Out:
#     SL   SW   PL   PW       Flower
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris.isnull().sum()
# Out:
# SL        0
# SW        0
# PL        0
# PW        0
# Flower    0
# dtype: int64

# %%
iris.dtypes
# Out:
# sl        float64
# sw        float64
# PL        float64
# PW        float64
# Flower     object
# dtype: object

# %%
for i in iris.columns:

# %%
iris.value_counts('SL')
# Out:
# SL
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 6.4     7
# 5.8     7
# 5.5     7
# 5.4     6
# 6.1     6
# 5.6     6
# 6.0     6
# 4.9     6
# 4.8     5
# 6.5     5
# 6.2     4
# 5.2     4
# 4.6     4
# 7.7     4
# 6.9     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 4.7     2
# 6.6     2
# 7.4     1
# 7.6     1
# 7.3     1
# 4.3     1
# 7.1     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#distribution plot
sns.distplot(iris.SL)
plt.show()

# %%
sns.histplot(iris.SL)
plt.show()

# %%
sns.displot(iris.SL)
plt.show()

# %%
sns.kdeplot(iris.SL)
plt.show()

# %%
sns.distplot(iris.SL[iris['Flower']=='Iris-setosa'],color='red')
sns.distplot(iris.SL[iris.Flower=='Iris-versicolor'],color='yellow')
sns.distplot(iris.SL[iris.Flower=='Iris-virginica'],color='g')
plt.show()

# %%
sns.displot(iris.SL[iris['Flower']=='Iris-setosa'],color='red')
sns.displot(iris.SL[iris.Flower=='Iris-versicolor'],color='yellow')
sns.displot(iris.SL[iris.Flower=='Iris-virginica'],color='g')
plt.show()

# %%
sns.histplot(iris.SL[iris.Flower=='Iris-setosa'],color='red')
sns.histplot(iris.SL[iris.Flower=='Iris-versicolor'],color='yellow')
sns.histplot(iris.SL[iris.Flower=='Iris-virginica'],color='g')
plt.show()

# %%
sns.kdeplot(iris.SL[iris['Flower']=='Iris-setosa'],color='red')
sns.kdeplot(iris.SL[iris.Flower=='Iris-versicolor'],color='yellow')
sns.kdeplot(iris.SL[iris.Flower=='Iris-virginica'],color='g')
plt.show()

# %%
sns.kdeplot(data=iris,fill=True,hatch='//*\\')
plt.show()

# %%
sns.kdeplot(data=iris,palette='cool')

# %%
#scatter plot
sns.scatterplot(x=iris.SL,y=iris.PL)
plt.show()

# %%
sns.scatterplot(x=iris.SL,y=iris.PL,hue=iris.Flower)
plt.show()

# %%
#count plot
sns.countplot(x=iris.Flower)
plt.show()

# %%
sns.countplot(

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=iris.SL,palette='cool')
plt.show()

# %%
#pair plot
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris,hue='Flower')
plt.show()

# %%
d=iris.drop('Flower',axis=1)
d.head()
# Out:
#     SL   SW   PL   PW
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
c=d.corr()
c
# Out:
#           SL        SW        PL        PW
# SL  1.000000 -0.109369  0.871754  0.817954
# SW -0.109369  1.000000 -0.420516 -0.356544
# PL  0.871754 -0.420516  1.000000  0.962757
# PW  0.817954 -0.356544  0.962757  1.000000

# %%
sns.heatmap(c,annot=True)
plt.show()

# %% [markdown]
# sns.heatmap(c,annot=True,cmap='Blues')
# plt.show()

# %%
sns.heatmap(c,annot=True)
plt.show()

# %%
#joint plot
sns.jointplot(data=iris)
plt.show()

# %%
sns.jointplot(iris,kind='kde')
plt.show()

# %%
sns.jointplot(iris,x=iris.SL,y=iris.PL,kind='kde')
plt.show()sns.ḍḍ
